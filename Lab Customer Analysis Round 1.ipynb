# %%
import pandas as pd
# Out:
# C:\Users\shakt\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv

# %%
df1 = pd.read_csv("file1.csv")
df2 = pd.read_csv("file2.csv")
df3 = pd.read_csv("file2.csv")

df1, df2, df3
# Out:
# (     Customer          ST GENDER             Education  \
#  0     RB50392  Washington    NaN                Master
#  1     QZ44356     Arizona      F              Bachelor
#  2     AI49188      Nevada      F              Bachelor
#  3     WW63253  California      M              Bachelor
#  4     GA49547  Washington      M  High School or Below
#  ...       ...         ...    ...                   ...
#  4003      NaN         NaN    NaN                   NaN
#  4004      NaN         NaN    NaN                   NaN
#  4005      NaN         NaN    NaN                   NaN
#  4006      NaN         NaN    NaN                   NaN
#  4007      NaN         NaN    NaN                   NaN
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
#  0                        NaN      0.0                1000.0
#  1                 697953.59%      0.0                  94.0
#  2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df1 = pd.DataFrame(df1)

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1 = df1[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Policy Type', 'Policy Type', 'Income', 'Monthly Premium Auto',
       'Number of Open Complaints', 'Total Claim Amount']]

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 697953.59%   Personal Auto   Personal Auto      0.0
# 2                1288743.17%   Personal Auto   Personal Auto  48767.0
# ...

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 697953.59%   Personal Auto   Personal Auto      0.0
# 2                1288743.17%   Personal Auto   Personal Auto  48767.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df2 = df2[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Policy Type', 'Policy Type', 'Income', 'Monthly Premium Auto',
       'Number of Open Complaints', 'Total Claim Amount']]

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%
# 1    CW49887  California      F    Master              462680.11%
# 2    MY31220  California      F   College              899704.02%
# 3    UH35128      Oregon      F   College             2580706.30%
# 4    WH52799     Arizona      F   College              380812.21%
# ..       ...         ...    ...       ...                     ...
# 991  HV85198     Arizona      M    Master              847141.75%
# 992  BS91566     Arizona      F   College              543121.91%
# 993  IL40123      Nevada      F   College              568964.41%
# 994  MY32149  California      F    Master              368672.38%
# 995  SA91515  California      M  Bachelor              399258.39%
#
#         Policy Type     Policy Type  Income  Monthly Premium Auto  \
# 0     Personal Auto   Personal Auto   16061                    88
# ...

# %%
df3
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3 = df3[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
       'Policy Type', 'Policy Type', 'Income', 'Monthly Premium Auto',
       'Number of Open Complaints', 'Total Claim Amount']]

# %%
df3
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%
# 1    CW49887  California      F    Master              462680.11%
# 2    MY31220  California      F   College              899704.02%
# 3    UH35128      Oregon      F   College             2580706.30%
# 4    WH52799     Arizona      F   College              380812.21%
# ..       ...         ...    ...       ...                     ...
# 991  HV85198     Arizona      M    Master              847141.75%
# 992  BS91566     Arizona      F   College              543121.91%
# 993  IL40123      Nevada      F   College              568964.41%
# 994  MY32149  California      F    Master              368672.38%
# 995  SA91515  California      M  Bachelor              399258.39%
#
#         Policy Type     Policy Type  Income  Monthly Premium Auto  \
# 0     Personal Auto   Personal Auto   16061                    88
# ...

# %%
pip install --upgrade pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
combined_df = pd.concat([df1, df2, df3], axis=0)

# %%
combined_df
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
import numpy as np

# %%
df_numerics_only = combined_df.select_dtypes(include=np.number)
df_numerics_only
# Out:
#       Income  Monthly Premium Auto  Total Claim Amount
# 0        0.0                1000.0            2.704934
# 1        0.0                  94.0         1131.464935
# 2    48767.0                 108.0          566.472247
# 3        0.0                 106.0          529.881344
# 4    36357.0                  68.0           17.269323
# ..       ...                   ...                 ...
# 991  63513.0                  70.0          185.667213
# 992  58161.0                  68.0          140.747286
# 993  83640.0                  70.0          471.050488
# 994      0.0                  96.0           28.460568
# 995      0.0                 111.0          700.349052
#
# [6000 rows x 3 columns]

# %%
dtype="category"

# %%
dtype
# Out:
# 'category'

# %%
df_select_Only_Category= combined_df.select_dtypes(exclude=np.number)
df_numerics_only
# Out:
#       Income  Monthly Premium Auto  Total Claim Amount
# 0        0.0                1000.0            2.704934
# 1        0.0                  94.0         1131.464935
# 2    48767.0                 108.0          566.472247
# 3        0.0                 106.0          529.881344
# 4    36357.0                  68.0           17.269323
# ..       ...                   ...                 ...
# 991  63513.0                  70.0          185.667213
# 992  58161.0                  68.0          140.747286
# 993  83640.0                  70.0          471.050488
# 994      0.0                  96.0           28.460568
# 995      0.0                 111.0          700.349052
#
# [6000 rows x 3 columns]

# %%
combined_df.dtypes
# Out:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Policy Type                   object
# Policy Type                   object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Total Claim Amount           float64
# dtype: object

# %%
float_columns = combined_df.select_dtypes(include=['float64']).columns
df_numeric = combined_df.drop(float_columns, axis=1)

# %%
combined_dataframes
# Out:
#     Customer          ST GENDER             Education  \
# 0    RB50392  Washington    NaN                Master
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 69795359.0   Personal Auto   Personal Auto      0.0
# 2                128874317.0   Personal Auto   Personal Auto  48767.0
# ...

# %%
combined_df.columns?

# %%
combined_df.DataFrame?
# Out:
# Object `combined_df.DataFrame` not found.

# %%
combined_df.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#       Policy Type     Policy Type   Income  Monthly Premium Auto  \
# 0   Personal Auto   Personal Auto      0.0                1000.0
# 1   Personal Auto   Personal Auto      0.0                  94.0
# 2   Personal Auto   Personal Auto  48767.0                 108.0
# 3  Corporate Auto  Corporate Auto      0.0                 106.0
# 4   Personal Auto   Personal Auto  36357.0                  68.0
#
#   Number of Open Complaints  Total Claim Amount
# 0                    1/0/00            2.704934
# ...

# %%
combined_df
# Out:
#     Customer          ST GENDER             Education Customer Lifetime Value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
combined_df.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#       Policy Type     Policy Type   Income  Monthly Premium Auto  \
# 0   Personal Auto   Personal Auto      0.0                1000.0
# 1   Personal Auto   Personal Auto      0.0                  94.0
# 2   Personal Auto   Personal Auto  48767.0                 108.0
# 3  Corporate Auto  Corporate Auto      0.0                 106.0
# 4   Personal Auto   Personal Auto  36357.0                  68.0
#
#   Number of Open Complaints  Total Claim Amount
# 0                    1/0/00            2.704934
# ...

# %%
combined_df.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Policy Type', 'Policy Type', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Total Claim Amount'],
#       dtype='object')

# %%
combined_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 991     True
# 992     True
# 993     True
# 994     True
# 995     True
# Length: 6000, dtype: bool

# %%
combined_df.drop_duplicates().reset_index()
# Out:
#       index Customer          ST GENDER             Education  \
# 0         0  RB50392  Washington    NaN                Master
# 1         1  QZ44356     Arizona      F              Bachelor
# 2         2  AI49188      Nevada      F              Bachelor
# 3         3  WW63253  California      M              Bachelor
# 4         4  GA49547  Washington      M  High School or Below
# ...     ...      ...         ...    ...                   ...
# 2060    991  HV85198     Arizona      M                Master
# 2061    992  BS91566     Arizona      F               College
# 2062    993  IL40123      Nevada      F               College
# 2063    994  MY32149  California      F                Master
# 2064    995  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 697953.59%   Personal Auto   Personal Auto      0.0
# ...

# %%
combined_df["Customer Lifetime Value"] = combined_df["Customer Lifetime Value"].astype(str).str.replace("%", "").astype(float)
combined_df["Customer Lifetime Value"] = combined_df["Customer Lifetime Value"] * 100

# %%
combined_df
# Out:
#     Customer          ST GENDER             Education  \
# 0    RB50392  Washington    NaN                Master
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 69795359.0   Personal Auto   Personal Auto      0.0
# 2                128874317.0   Personal Auto   Personal Auto  48767.0
# ...

# %%
combined_df[combined_df['Income']>=0]
# Out:
#     Customer          ST GENDER             Education  \
# 0    RB50392  Washington    NaN                Master
# 1    QZ44356     Arizona      F              Bachelor
# 2    AI49188      Nevada      F              Bachelor
# 3    WW63253  California      M              Bachelor
# 4    GA49547  Washington      M  High School or Below
# ..       ...         ...    ...                   ...
# 991  HV85198     Arizona      M                Master
# 992  BS91566     Arizona      F               College
# 993  IL40123      Nevada      F               College
# 994  MY32149  California      F                Master
# 995  SA91515  California      M              Bachelor
#
#      Customer Lifetime Value     Policy Type     Policy Type   Income  \
# 0                        NaN   Personal Auto   Personal Auto      0.0
# 1                 69795359.0   Personal Auto   Personal Auto      0.0
# 2                128874317.0   Personal Auto   Personal Auto  48767.0
# ...
